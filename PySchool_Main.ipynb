# %%
#import dependencies 
import pandas as pd

# %%
#create a path for file
school_path = "/Users/kscomputer/Desktop/PyCitySchools/pandas-challenge/Resources/students_complete.csv"
district_path = "/Users/kscomputer/Desktop/PyCitySchools/pandas-challenge/Resources/schools_complete.csv"

# %%
#read district_path to a dataframe and get a snapshot
district_charter_df = pd.read_csv(district_path)

district_charter_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#read school_path to a dataframe and get a snapshot of data
school_all_df = pd.read_csv(school_path)

school_all_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#merged school_all and district_charter dfs to one dataframe on 'school name' 
merged_df = pd.merge(school_all_df,district_charter_df, on='school_name')

merged_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Start of District Summary Creation

# %%
#find schools that are only in district. Remove Charter. 
district_size_df = district_charter_df.loc[district_charter_df['type']=='District',:]

district_size_df.head()
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 3           3  Hernandez High School  District  4635  3022020
# 7           7     Bailey High School  District  4976  3124928
# 11         11  Rodriguez High School  District  3999  2547363

# %%
#find lenth of school id to determine how many schools are in district
district_size_count = district_size_df['School ID']

district_size= len(district_size_count)

district_size
# Out:
# 7

# %%
#find sum of students in the district
district_student_sum = district_size_df['size'].sum()

district_student_sum
# Out:
# 26976

# %%
#find sum of budget for district
district_budget_sum = district_size_df['budget'].sum()

district_budget_sum
# Out:
# 17347923

# %%
#inner merge on district_size and school_all to make calculations for average math score,reading, and percent
math_reading_df = pd.merge(district_size_df, school_all_df[['reading_score','math_score','school_name']], on='school_name')

math_reading_df
# Out:
#        School ID        school_name      type  size   budget  reading_score  \
# 0              0  Huang High School  District  2917  1910635             66
# 1              0  Huang High School  District  2917  1910635             94
# 2              0  Huang High School  District  2917  1910635             90
# 3              0  Huang High School  District  2917  1910635             67
# 4              0  Huang High School  District  2917  1910635             97
# ...          ...                ...       ...   ...      ...            ...
# 26971         13   Ford High School  District  2739  1763916             63
# 26972         13   Ford High School  District  2739  1763916             94
# 26973         13   Ford High School  District  2739  1763916             91
# 26974         13   Ford High School  District  2739  1763916             75
# 26975         13   Ford High School  District  2739  1763916             76
#
#        math_score
# 0              79
# ...

# %%
#merge dataframe math_reading is good. 
math_reading_df['school_name'].value_counts()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Name: school_name, dtype: int64

# %%
#avaerage math for district 
average_math_district = math_reading_df['math_score'].mean()

average_math_district
# Out:
# 76.98702550415184

# %%
#average reading for district
average_reading_district = math_reading_df['reading_score'].mean()

average_reading_district
# Out:
# 80.96248517200475

# %%
#percent passing math district
passing_math_district = (math_reading_df['math_score']>=70).sum()

percent_math_district = (passing_math_district/26976)*100

percent_math_district
# Out:
# 66.51838671411625

# %%
#percent passing reading
passing_reading_district = (math_reading_df['reading_score']>=70).sum()

percent_reading_district = (passing_reading_district/26976)*100 

percent_reading_district
# Out:
# 80.90524911032028

# %%
#percent passing math and reading
passing_reading_math_district = ((math_reading_df['reading_score']>=70)& (math_reading_df['math_score']>=70)).sum()

percent_reading_math_district = (passing_reading_math_district/26976)*100

percent_reading_math_district
# Out:
# 53.695877817319094

# %%
#summary table for district
summary_district = {'Total Schools':[district_size],
                      'Total Students':[district_student_sum],
                      'Total Budget':[district_budget_sum],
                      'Average Math Score':[average_math_district],
                      'Average Reading Score':[average_reading_district],
                      '% Passing Math': [percent_math_district],
                      '% Passing Reading':[percent_reading_district],
                      '% Overall Passing':[percent_reading_math_district]}

summary_district_df = pd.DataFrame(data = summary_district)
summary_district_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0              7           26976      17347923           76.987026
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0              80.962485       66.518387          80.905249          53.695878

# %%
#taking merged_df and re organizing for the information we need beginning of school summary
school_df = merged_df[['school_name','type','size','budget','math_score','reading_score']]

school_df
# Out:
#               school_name      type  size   budget  math_score  reading_score
# 0       Huang High School  District  2917  1910635          79             66
# 1       Huang High School  District  2917  1910635          61             94
# 2       Huang High School  District  2917  1910635          60             90
# 3       Huang High School  District  2917  1910635          58             67
# 4       Huang High School  District  2917  1910635          84             97
# ...                   ...       ...   ...      ...         ...            ...
# 39165  Thomas High School   Charter  1635  1043130          90             99
# 39166  Thomas High School   Charter  1635  1043130          70             95
# 39167  Thomas High School   Charter  1635  1043130          84             73
# 39168  Thomas High School   Charter  1635  1043130          90             99
# 39169  Thomas High School   Charter  1635  1043130          75             95
#
# [39170 rows x 6 columns]

# %%
school_type = school_df.groupby(['school_name'])['type']

school_t = school_type.unique()

school_t
# Out:
# school_name
# Bailey High School       [District]
# Cabrera High School       [Charter]
# Figueroa High School     [District]
# Ford High School         [District]
# Griffin High School       [Charter]
# Hernandez High School    [District]
# Holden High School        [Charter]
# Huang High School        [District]
# Johnson High School      [District]
# Pena High School          [Charter]
# Rodriguez High School    [District]
# Shelton High School       [Charter]
# Thomas High School        [Charter]
# Wilson High School        [Charter]
# Wright High School        [Charter]
# Name: type, dtype: object

# %%
schools_budget = school_df.groupby(['school_name'])['budget']
#merged_df['budget'].value_counts()

school_b = schools_budget.unique()

school_b
# Out:
# school_name
# Bailey High School       [3124928]
# Cabrera High School      [1081356]
# Figueroa High School     [1884411]
# Ford High School         [1763916]
# Griffin High School       [917500]
# Hernandez High School    [3022020]
# Holden High School        [248087]
# Huang High School        [1910635]
# Johnson High School      [3094650]
# Pena High School          [585858]
# Rodriguez High School    [2547363]
# Shelton High School      [1056600]
# Thomas High School       [1043130]
# Wilson High School       [1319574]
# Wright High School       [1049400]
# Name: budget, dtype: object

# %%
per_school_students = school_df.groupby(['school_name'])['size']

students_t = per_school_students.unique()
students_t
# Out:
# school_name
# Bailey High School       [4976]
# Cabrera High School      [1858]
# Figueroa High School     [2949]
# Ford High School         [2739]
# Griffin High School      [1468]
# Hernandez High School    [4635]
# Holden High School        [427]
# Huang High School        [2917]
# Johnson High School      [4761]
# Pena High School          [962]
# Rodriguez High School    [3999]
# Shelton High School      [1761]
# Thomas High School       [1635]
# Wilson High School       [2283]
# Wright High School       [1800]
# Name: size, dtype: object

# %%
#find per student budget
per_school = school_b/students_t

per_school
# Out:
# school_name
# Bailey High School       [628.0]
# Cabrera High School      [582.0]
# Figueroa High School     [639.0]
# Ford High School         [644.0]
# Griffin High School      [625.0]
# Hernandez High School    [652.0]
# Holden High School       [581.0]
# Huang High School        [655.0]
# Johnson High School      [650.0]
# Pena High School         [609.0]
# Rodriguez High School    [637.0]
# Shelton High School      [600.0]
# Thomas High School       [638.0]
# Wilson High School       [578.0]
# Wright High School       [583.0]
# dtype: object

# %%
#updated data frame created with mean for math_score and reading_score
average_math =school_df.groupby(['school_name']) ['math_score'].mean()
average_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#make sure data displays how I think
average_read = school_df.groupby(['school_name'])['reading_score'].mean()
average_read
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
math_s = school_df.loc[school_df['math_score']>=70]

math_p = (math_s.groupby(['school_name']).count()['budget']/school_df.groupby(['school_name']).count()['budget'])*100

math_p
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: budget, dtype: float64

# %%
reading_s = school_df.loc[school_df['reading_score']>=70]

reading_p = (reading_s.groupby(["school_name"]).count()["budget"]/school_df.groupby(["school_name"]).count()["budget"])*100

reading_p
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: budget, dtype: float64

# %%
#indivduals who meet criteria of passing reading and math
read_math_s = school_df.loc[(school_df['reading_score']>=70) & (school_df['math_score']>=70)]

read_math_p = (read_math_s.groupby(['school_name']).count()['budget']/school_df.groupby(['school_name']).count()['budget'])*100

read_math_p
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: budget, dtype: float64

# %%
school_summary = pd.DataFrame({'School Type':school_t,
    'Total Students':students_t,
                   'Total School Budget':school_b,
                    'Per Student Budget': per_school,           
                   'Average Math Score':average_math,
                   'Average Reading Score':average_read,
                   '% Passing Math':math_p,
                   '% Passing Reading':reading_p,
                   '% Overall Passing':read_math_p

                  })
school_summary.rename_axis(None, axis=0)
# Out:
#                       School Type Total Students Total School Budget  \
# Bailey High School     [District]         [4976]           [3124928]
# Cabrera High School     [Charter]         [1858]           [1081356]
# Figueroa High School   [District]         [2949]           [1884411]
# Ford High School       [District]         [2739]           [1763916]
# Griffin High School     [Charter]         [1468]            [917500]
# Hernandez High School  [District]         [4635]           [3022020]
# Holden High School      [Charter]          [427]            [248087]
# Huang High School      [District]         [2917]           [1910635]
# Johnson High School    [District]         [4761]           [3094650]
# Pena High School        [Charter]          [962]            [585858]
# Rodriguez High School  [District]         [3999]           [2547363]
# Shelton High School     [Charter]         [1761]           [1056600]
# Thomas High School      [Charter]         [1635]           [1043130]
# ...

# %%
top_five = school_summary.sort_values('% Overall Passing', ascending=False)


top_five.head(5)
# Out:
#                     School Type Total Students Total School Budget  \
# school_name
# Cabrera High School   [Charter]         [1858]           [1081356]
# Thomas High School    [Charter]         [1635]           [1043130]
# Griffin High School   [Charter]         [1468]            [917500]
# Wilson High School    [Charter]         [2283]           [1319574]
# Pena High School      [Charter]          [962]            [585858]
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            [582.0]           83.061895
# Thomas High School             [638.0]           83.418349
# Griffin High School            [625.0]           83.351499
# Wilson High School             [578.0]           83.274201
# Pena High School               [609.0]           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
bottom_five = school_summary.sort_values('% Overall Passing')

bottom_five.head(5)
# Out:
#                       School Type Total Students Total School Budget  \
# school_name
# Rodriguez High School  [District]         [3999]           [2547363]
# Figueroa High School   [District]         [2949]           [1884411]
# Huang High School      [District]         [2917]           [1910635]
# Hernandez High School  [District]         [4635]           [3022020]
# Johnson High School    [District]         [4761]           [3094650]
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            [637.0]           76.842711
# Figueroa High School             [639.0]           76.711767
# Huang High School                [655.0]           76.629414
# Hernandez High School            [652.0]           77.289752
# Johnson High School              [650.0]           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Rodriguez High School              80.744686       66.366592
# ...

# %%
#math score by grade step 1 make a smaller data frame
grades_math_df = school_all_df[['grade','school_name','math_score']]

grades_math_df.head()
# Out:
#   grade        school_name  math_score
# 0   9th  Huang High School          79
# 1  12th  Huang High School          61
# 2  12th  Huang High School          60
# 3  12th  Huang High School          58
# 4   9th  Huang High School          84

# %%
#math score by grade step 2 group 'school name' and 'grade' together to isolate 'math score'
math_test = grades_math_df.groupby(['school_name','grade'])

# %%
#math score by grade step 3 take 'math_test'and .mean
math_t = math_test.mean()

math_t.T
# Out:
# school_name Bailey High School                                   \
# grade                     10th       11th       12th        9th
# math_score           76.996772  77.515588  76.492218  77.083676
#
# school_name Cabrera High School                                  \
# grade                      10th      11th       12th        9th
# math_score            83.154506  82.76556  83.277487  83.094697
#
# school_name Figueroa High School             ... Thomas High School  \
# grade                       10th       11th  ...               12th
# math_score             76.539974  76.884344  ...          83.497041
#
# school_name            Wilson High School                                   \
# grade              9th               10th       11th       12th        9th
# math_score   83.590022          83.724422  83.195326  83.035794  83.085578
#
# school_name Wright High School
# grade                     10th       11th       12th        9th
# ...

# %%
#reading score by grade step 1 make a smaller data frame
grades_reading_df = school_all_df[['grade','school_name','reading_score']]
                                   
grades_reading_df.head()
# Out:
#   grade        school_name  reading_score
# 0   9th  Huang High School             66
# 1  12th  Huang High School             94
# 2  12th  Huang High School             90
# 3  12th  Huang High School             67
# 4   9th  Huang High School             97

# %%
#math score by grade step 2 group 'school name' and 'grade' together to isolate 'reading score'
reading_test = grades_reading_df.groupby(['school_name','grade'])

# %%
#math score by grade step 3 take 'reading_test'and .mean
read_t = reading_test.mean()

#do not play with here up
read_t.T
# Out:
# school_name   Bailey High School                                   \
# grade                       10th       11th       12th        9th
# reading_score          80.907183  80.945643  80.912451  81.303155
#
# school_name   Cabrera High School                                   \
# grade                        10th       11th       12th        9th
# reading_score           84.253219  83.788382  84.287958  83.676136
#
# school_name   Figueroa High School             ... Thomas High School  \
# grade                         10th       11th  ...               12th
# reading_score            81.408912  80.640339  ...          83.831361
#
# school_name             Wilson High School                                   \
# grade               9th               10th       11th       12th        9th
# reading_score  83.72885          84.021452  83.764608  84.317673  83.939778
#
# school_name   Wright High School
# grade                       10th       11th       12th        9th
# ...

# %%
scores_by_s = school_summary[['Average Math Score','Average Reading Score','% Passing Math',
                             '% Passing Reading',"% Overall Passing",'Per Student Budget']]

scores_by_s
# Out:
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
#0 to 584, 584 to 629, 629 to 644, 644 to 675
bins = [0,584,629,644,675]

group_a = ['<$584','$584-$629','$630-$644','$645-$675']

# %%
#names for bins
scores_by_s['Spending Ranges']= pd.cut(scores_by_s['Per Student Budget'], bins, labels=group_a)

scores_by_s
# Out:
# /Users/kscomputer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# ...

# %%
scores_by_s.dtypes
# Out:
# Average Math Score        float64
# Average Reading Score     float64
# % Passing Math            float64
# % Passing Reading         float64
# % Overall Passing         float64
# Per Student Budget         object
# Spending Ranges          category
# dtype: object

# %%
scores_by_spend = scores_by_s.groupby(['Spending Ranges'])

scores_by_spend.mean()
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# Spending Ranges
# <$584                     83.455399              83.933814       93.460096
# $584-$629                 81.899826              83.155286       87.133538
# $630-$644                 78.518855              81.624473       73.484209
# $645-$675                 76.997210              81.027843       66.164813
#
#                  % Passing Reading  % Overall Passing
# Spending Ranges
# <$584                    96.610877          90.369459
# $584-$629                92.718205          81.418596
# $630-$644                84.391793          62.857656
# $645-$675                81.133951          53.526855

# %%
size_s = school_summary[['Average Math Score','Average Reading Score','% Passing Math',
                             '% Passing Reading',"% Overall Passing",'Total Students']]

size_s
# Out:
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
bin_s = [0,1000,2000,5000]

group_b = ['Small (<1000)','Medium (1000-2000)','Large(2000-5000)']

# %%
size_s['School Size']= pd.cut(size_s['Total Students'], bin_s, labels=group_b)

size_s
# Out:
# /Users/kscomputer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                        Average Math Score  Average Reading Score  \
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# ...

# %%
size_by = size_s.groupby(['School Size'])

size_by.mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large(2000-5000)             77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large(2000-5000)            82.766634          58.286003

# %%
chartdis_s = school_summary[['School Type','Average Math Score','Average Reading Score','% Passing Math',
                             '% Passing Reading','% Overall Passing']]

chartdis_s
# Out:
#                       School Type  Average Math Score  Average Reading Score  \
# school_name
# Bailey High School     [District]           77.048432              81.033963
# Cabrera High School     [Charter]           83.061895              83.975780
# Figueroa High School   [District]           76.711767              81.158020
# Ford High School       [District]           77.102592              80.746258
# Griffin High School     [Charter]           83.351499              83.816757
# Hernandez High School  [District]           77.289752              80.934412
# Holden High School      [Charter]           83.803279              83.814988
# Huang High School      [District]           76.629414              81.182722
# Johnson High School    [District]           77.072464              80.966394
# Pena High School        [Charter]           83.839917              84.044699
# Rodriguez High School  [District]           76.842711              80.744686
# ...

# %%
chartdis_s.dtypes
# Out:
# School Type               object
# Average Math Score       float64
# Average Reading Score    float64
# % Passing Math           float64
# % Passing Reading        float64
# % Overall Passing        float64
# dtype: object

# %%
chartdis_s.rename_axis(None , axis=0)

chartdis_s.set_index('School Type')
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# [District]            77.048432              81.033963       66.680064
# [Charter]             83.061895              83.975780       94.133477
# [District]            76.711767              81.158020       65.988471
# [District]            77.102592              80.746258       68.309602
# [Charter]             83.351499              83.816757       93.392371
# [District]            77.289752              80.934412       66.752967
# [Charter]             83.803279              83.814988       92.505855
# [District]            76.629414              81.182722       65.683922
# [District]            77.072464              80.966394       66.057551
# [Charter]             83.839917              84.044699       94.594595
# [District]            76.842711              80.744686       66.366592
# [Charter]             83.359455              83.725724       93.867121
# ...

# %%
chartdis_s.groupby('School Type').mean()
