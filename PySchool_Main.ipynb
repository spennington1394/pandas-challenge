# %%
import pandas as pd

# %%
school_path = "/Users/kscomputer/Desktop/PyCitySchools/pandas-challenge/Resources/students_complete.csv"
district_path = "/Users/kscomputer/Desktop/PyCitySchools/pandas-challenge/Resources/schools_complete.csv"

# %%
district_charter_df = pd.read_csv(district_path)



district_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
school_all_df = pd.read_csv(school_path)

school_all_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# 3                 67          58
# 4                 97          84
# ...              ...         ...
# 39165             99          90
# 39166             95          70
# 39167             73          84
# 39168             99          90
# 39169             95          75
#
# [39170 rows x 7 columns]

# %%
#merged dataframe where index can be set to make school summary easier
merged_df = pd.merge(school_all_df,district_charter_df, on='school_name', how='outer')

merged_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
#find schools that are only in district. Remove Charter. 
district_size_df = district_charter_df.loc[district_charter_df['type']=='District',:]

district_size_df.head()
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 3           3  Hernandez High School  District  4635  3022020
# 7           7     Bailey High School  District  4976  3124928
# 11         11  Rodriguez High School  District  3999  2547363

# %%
#find count of school name to determine how many schools are in district
district_size_count = district_size_df['School ID']

district_size= len(district_size_count)

district_size
# Out:
# 7

# %%
#find sum of students in the district
district_student_sum = district_size_df['size'].sum()

district_student_sum
# Out:
# 26976

# %%
#find sum of budget for district
district_budget_sum = district_size_df['budget'].sum()

district_budget_sum
# Out:
# 17347923

# %%
#using isin to get dataframe school_all narrowed down to schools in district
school_district = school_all_df['school_name'].isin(['Huang High School',
                                                       'Figueroa High School',
                                                       'Hernandez High School',
                                                       'Bailey High School',
                                                       'Rodriguez High School',
                                                        'Johnson High School',
                                                        'Ford High School'])
school_all_df[school_district].head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#average math for district
average_math_district = school_all_df[school_district]['math_score'].mean()

average_math_district
# Out:
# 76.98702550415184

# %%
#average reading for district
average_reading_district = school_all_df[school_district]['reading_score'].mean()

average_reading_district
# Out:
# 80.96248517200475

# %%
#percent passing math
percent_passing_math = school_all_df[schooldistrict].loc[school_all_df[school_district]['math_score']>70]

percent_passing_math
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-53a1f41d6690> in <module>
#       1 #percent passing math
# ----> 2 percent_passing_math = school_all_df[schooldistrict].loc[school_all_df[school_district]['math_score']>70]
#       3
#       4 percent_passing_math
#
# NameError: name 'schooldistrict' is not defined

# %%
#percent passing reading

# %%
#percent passing math and reading

# %%
#here to make percent and average easier
school_df= merged_df.set_index('school_name')

school_df
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       39165       Donna Howard      F  12th             99
# Thomas High School       39166          Dawn Bell      F  10th             95
# Thomas High School       39167     Rebecca Tanner      F   9th             73
# Thomas High School       39168       Desiree Kidd      F  10th             99
# Thomas High School       39169    Carolyn Jackson      F  11th             95
#
#                     math_score  School ID      type  size   budget
# school_name
# Huang High School           79          0  District  2917  1910635
# Huang High School           61          0  District  2917  1910635
# Huang High School           60          0  District  2917  1910635
# Huang High School           58          0  District  2917  1910635
# Huang High School           84          0  District  2917  1910635
# ...                        ...        ...       ...   ...      ...
# Thomas High School          90         14   Charter  1635  1043130
# Thomas High School          70         14   Charter  1635  1043130
# Thomas High School          84         14   Charter  1635  1043130
# Thomas High School          90         14   Charter  1635  1043130
# Thomas High School          75         14   Charter  1635  1043130
#
# [39170 rows x 10 columns]

# %%
#school name -not indexed in alphabetical order
school_name = district_df['school_name']

school_name
# Out:
# 0         Huang High School
# 1      Figueroa High School
# 2       Shelton High School
# 3     Hernandez High School
# 4       Griffin High School
# 5        Wilson High School
# 6       Cabrera High School
# 7        Bailey High School
# 8        Holden High School
# 9          Pena High School
# 10       Wright High School
# 11    Rodriguez High School
# 12      Johnson High School
# 13         Ford High School
# 14       Thomas High School
# Name: school_name, dtype: object

# %%
#School summary total students per school-not indexed in alphabetical order
school_students_count= district_df['size']

school_students_count
# Out:
# 0     2917
# 1     2949
# 2     1761
# 3     4635
# 4     1468
# 5     2283
# 6     1858
# 7     4976
# 8      427
# 9      962
# 10    1800
# 11    3999
# 12    4761
# 13    2739
# 14    1635
# Name: size, dtype: int64

# %%
#school budget total
school_budget= district_df['budget']

school_budget
# Out:
# 0     1910635
# 1     1884411
# 2     1056600
# 3     3022020
# 4      917500
# 5     1319574
# 6     1081356
# 7     3124928
# 8      248087
# 9      585858
# 10    1049400
# 11    2547363
# 12    3094650
# 13    1763916
# 14    1043130
# Name: budget, dtype: int64

# %%
#per student budget-not indexed alphabetically- values are correct but not in that order
schools_per_student_budget = district_df['budget']/district_df['size']

schools_per_student_budget
# Out:
# 0     655.0
# 1     639.0
# 2     600.0
# 3     652.0
# 4     625.0
# 5     578.0
# 6     582.0
# 7     628.0
# 8     581.0
# 9     609.0
# 10    583.0
# 11    637.0
# 12    650.0
# 13    644.0
# 14    638.0
# dtype: float64

# %%
#average math per school
average_math_per_school =

# %%
#average reading per school

# %%
#percent passed math -passing = 70

# %%
#percent passed reading- passing = 70

# %%
#percent passed math and reading

# %%
#redo and clean the data so that school_df has not charters and then remerge. Will be able to work off of one dataset then
